# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno

# %%
diabetes_df = pd.read_csv('/content/diabetes.csv')
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_df[diabetes_df.columns[1:6]] = diabetes_df[diabetes_df.columns[1:6]].replace(0,np.nan)
diabetes_df.isna().sum().sum()
# Out:
# 652

# %% [markdown]
# ## IMPUTACION POR MEDIA,MEDIANA,MODA

# %%
diabetes_df.Glucose.isna().sum()
# Out:
# 5

# %%
sorted_df = diabetes_df.sort_values(
    by=['Glucose'],
    ascending=False
)
sorted_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1    199.0           76.0           43.0      NaN  42.9
# 561            0    198.0           66.0           32.0    274.0  41.3
# 228            4    197.0           70.0           39.0    744.0  36.7
# 408            8    197.0           74.0            NaN      NaN  25.9
# 8              2    197.0           70.0           45.0    543.0  30.5
# ..           ...      ...            ...            ...      ...   ...
# 75             1      NaN           48.0           20.0      NaN  24.7
# 182            1      NaN           74.0           20.0     23.0  27.7
# 342            1      NaN           68.0           35.0      NaN  32.0
# 349            5      NaN           80.0           32.0      NaN  41.0
# 502            6      NaN           68.0           41.0      NaN  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 661                     1.394   22        1
# ...

# %%
sorted_df['Glucose'].mean()
# Out:
# 121.6867627785059

# %%
diabates_glucose_df = diabetes_df
diabates_glucose_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabates_glucose_df["Glucose"] = diabates_glucose_df["Glucose"].fillna(diabates_glucose_df["Glucose"].mean())
sorted_glucose_df = diabates_glucose_df.sort_values(
    by=['Glucose'],
    ascending=False
)
sorted_glucose_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1    199.0           76.0           43.0      NaN  42.9
# 561            0    198.0           66.0           32.0    274.0  41.3
# 228            4    197.0           70.0           39.0    744.0  36.7
# 8              2    197.0           70.0           45.0    543.0  30.5
# 579            2    197.0           70.0           99.0      NaN  34.7
# ..           ...      ...            ...            ...      ...   ...
# 352            3     61.0           82.0           28.0      NaN  34.4
# 146            9     57.0           80.0           37.0      NaN  32.8
# 537            0     57.0           60.0            NaN      NaN  21.7
# 680            2     56.0           56.0           28.0     45.0  24.2
# 62             5     44.0           62.0            NaN      NaN  25.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 661                     1.394   22        1
# ...

# %%
sorted_glucose_df['Glucose'].mean()
# Out:
# 121.68676277850591

# %% [markdown]
# IMPUTACION POR MEDIANA

# %%
diabetes_df['Glucose'].median()
# Out:
# 117.0

# %%
diabates_glucose_median_df = diabetes_df
diabates_glucose_median_df["Glucose"] = diabates_glucose_median_df["Glucose"].fillna(diabates_glucose_median_df["Glucose"].median())
sorted_glucose_median_df = diabates_glucose_median_df.sort_values(
    by=['Glucose'],
    ascending=False
)
sorted_glucose_median_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1    199.0           76.0           43.0      NaN  42.9
# 561            0    198.0           66.0           32.0    274.0  41.3
# 228            4    197.0           70.0           39.0    744.0  36.7
# 8              2    197.0           70.0           45.0    543.0  30.5
# 579            2    197.0           70.0           99.0      NaN  34.7
# ..           ...      ...            ...            ...      ...   ...
# 352            3     61.0           82.0           28.0      NaN  34.4
# 146            9     57.0           80.0           37.0      NaN  32.8
# 537            0     57.0           60.0            NaN      NaN  21.7
# 680            2     56.0           56.0           28.0     45.0  24.2
# 62             5     44.0           62.0            NaN      NaN  25.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 661                     1.394   22        1
# ...

# %%
sorted_glucose_median_df['Glucose'].median()
# Out:
# 117.0

# %% [markdown]
# ## IMPUTACION POR BFILL Y FFILL ( LLENADO HACIA ADELANTE Y LLENADO HACIA ATRAS)

# %%
sorted_skin_thickness_df = diabetes_df.sort_values(
    by=['Age','Glucose'],
    ascending=True
)
sorted_skin_thickness_df.SkinThickness.isna().sum()
# Out:
# 227

# %%
 sorted_skin_thickness_df.SkinThickness
# Out:
# 273    50.0
# 55     10.0
# 290    29.0
# 90      NaN
# 60      NaN
#        ...
# 123     NaN
# 684     NaN
# 666    18.0
# 453     NaN
# 459    33.0
# Name: SkinThickness, Length: 768, dtype: float64

# %%
 sorted_skin_thickness_df.SkinThickness.ffill()
# Out:
# 273    50.0
# 55     10.0
# 290    29.0
# 90     29.0
# 60     29.0
#        ...
# 123    37.0
# 684    37.0
# 666    18.0
# 453    18.0
# 459    33.0
# Name: SkinThickness, Length: 768, dtype: float64

# %%
plt.figure(figsize=(20,10))
diabetes_df['SkinThickness'].ffill().plot(color='red',marker='o',alpha=6/9,linestyle='dashed')
diabetes_df['SkinThickness'].plot(color='#313638',marker='o',alpha=6/9,linestyle='dashed')
plt.legend()
plt.show()

# %%
sorted_skin_thickness_df['SkinThickness'] = sorted_skin_thickness_df['SkinThickness'].ffill()
sorted_skin_thickness_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 273            1     71.0           78.0           50.0     45.0  33.2
# 55             1     73.0           50.0           10.0      NaN  23.0
# 290            0     78.0           88.0           29.0     40.0  36.9
# 90             1     80.0           55.0           29.0      NaN  19.1
# 60             2     84.0            NaN           29.0      NaN   NaN
# ..           ...      ...            ...            ...      ...   ...
# 123            5    132.0           80.0           37.0      NaN  26.8
# 684            5    136.0           82.0           37.0      NaN   NaN
# 666            4    145.0           82.0           18.0      NaN  32.5
# 453            2    119.0            NaN           18.0      NaN  19.6
# 459            9    134.0           74.0           33.0     60.0  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 273                     0.422   21        0
# ...

# %% [markdown]
# IMPUTACION POR INTERPOLACIÓN

# %%
sorted_insulin_df = diabetes_df
sorted_insulin_df.Insulin.isna().sum()
sorted_insulin_df.Insulin
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3       94.0
# 4      168.0
#        ...
# 763    180.0
# 764      NaN
# 765    112.0
# 766      NaN
# 767      NaN
# Name: Insulin, Length: 768, dtype: float64

# %%
plt.figure(figsize=(20,10))
diabetes_df['Insulin'].ffill().plot(color='red',marker='o',alpha=6/9,linestyle='dashed')
diabetes_df['Insulin'].plot(color='#313638',marker='o',alpha=6/9,linestyle='dashed')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))
diabetes_df['Insulin'].interpolate(method='linear').plot(color='red',marker='o',alpha=6/9,linestyle='dashed')
diabetes_df['Insulin'].plot(color='#313638',marker='o',alpha=6/9,linestyle='dashed')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))
diabetes_df['Insulin'].interpolate(method='quadratic').plot(color='red',marker='o',alpha=6/9,linestyle='dashed')
diabetes_df['Insulin'].plot(color='#313638',marker='o',alpha=6/9,linestyle='dashed')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))
diabetes_df['Insulin'].interpolate(method='nearest').plot(color='red',marker='o',alpha=6/9,linestyle='dashed')
diabetes_df['Insulin'].plot(color='#313638',marker='o',alpha=6/9,linestyle='dashed')
plt.legend()
plt.show()

# %%
sorted_insuline_df = diabetes_df
sorted_insuline_df['Insulin']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3       94.0
# 4      168.0
#        ...
# 763    180.0
# 764    146.0
# 765    112.0
# 766    112.0
# 767    112.0
# Name: Insulin, Length: 768, dtype: float64

# %%
sorted_insuline_df['Insulin'].interpolate(method='linear',limit_direction='both',inplace=True)
sorted_insuline_df['Insulin'].isna().sum()
# Out:
# 0

# %%
sorted_insuline_df['Insulin']
# Out:
# 0       94.0
# 1       94.0
# 2       94.0
# 3       94.0
# 4      168.0
#        ...
# 763    180.0
# 764    146.0
# 765    112.0
# 766    112.0
# 767    112.0
# Name: Insulin, Length: 768, dtype: float64
