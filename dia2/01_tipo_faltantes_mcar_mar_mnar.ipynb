# %% [markdown]
# # PASO 1 - IMPORTAR LIBRERIAS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno

# %% [markdown]
# # PASO 2 - EJECUTAR FUNCIONES MISSING

# %%
# %run '/content/pandas_missing_extension_2.ipynb'
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for upsetplot: filename=UpSetPlot-0.9.0-py3-none-any.whl size=24816 sha256=80227022a4c099e68fa42c094cb429e922813607612d061b9c059608f55880cc
#   Stored in directory: /root/.cache/pip/wheels/73/42/9f/1c9718ea27f30466d2787e0f7d88a7cb11942e3460c17e0ef6
# Successfully built upsetplot
# ...

# %% [markdown]
# # PASO 3 - CARGAMOS DATASET

# %%
diabetes_df = pd.read_csv('/content/diabetes.csv')
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # PASO 4  - TRABAJAMOS CON LOS NULOS

# %%
diabetes_df.missing.number_missing()
# Out:
# 0

# %% [markdown]
# ## COMO NO HAY NULOS LOS VAMOS A GENERAR

# %%
diabetes_df[diabetes_df.columns[1:6]] = diabetes_df[diabetes_df.columns[1:6]].replace(0,np.nan)
diabetes_df.missing.number_missing()
# Out:
# 652

# %% [markdown]
# ## GRAFICAMOS NUESTROS NULOS

# %%
diabetes_df.missing.missing_variable_plot()
