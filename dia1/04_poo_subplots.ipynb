# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
fig,axes = plt.subplots()

axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y,'b--')
axes[1].hist(y)
# Out:
# (array([4., 1., 1., 1., 1., 0., 1., 0., 1., 1.]),
#  array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2)
ax1.plot(x,y,'b')
ax2.plot(y,x,'r')

# %%
fig,axes = plt.subplots(2,4)
axes[0,0].plot(x,np.cos(x))
axes[0,1].plot(x,np.sin(x),'y')
axes[0,2].plot(x,np.tan(x),'r')
axes[0,3].plot(x,np.cos(x)**2)
axes[1,0].plot(y,np.cos(y))
axes[1,1].plot(y,np.sin(y),'g')
axes[1,2].plot(y,np.tan(y),'y')
axes[1,3].plot(y,np.cos(y)**2)
fig.tight_layout()
