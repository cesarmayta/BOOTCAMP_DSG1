# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
amazon_df = pd.read_csv('/content/amazon_product.csv')
amazon_df
# Out:
#     Unnamed: 0        asin                                      product_title  \
# 0            0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1            1  B0CTD47P22  SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...
# 2            2  B0CHH6X6H2  Total by Verizon | Samsung Galaxy A03s | Locke...
# 3            3  B0BZ9XNBRB  Google Pixel 7a - Unlocked Android Cell Phone ...
# 4            4  B0CN1QSH8Q  SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...
# ..         ...         ...                                                ...
# 59          59  B0D6LWXK1R  Greatish Hits: I Followed My Dreams and My Dre...
# 60          60  B0CLKQF5HR                                          Swan Song
# 61          61  B0BZFHK12K                            Bluey: Let&#x27;s Play!
# 62          62  B09Z7J4L6X  Xbox Wireless Controller – Sky Cipher Special ...
# 63          63  B0CT2R7199  HP DeskJet 2855e Wireless All-in-One Color Ink...
#
# ...

# %% [markdown]
# TIPOS DE DATOS

# %%
amazon_df.dtypes.value_counts()
# Out:
# object     12
# bool        5
# int64       3
# float64     2
# Name: count, dtype: int64

# %% [markdown]
# CORRELACIONES

# %%
amazon_df.corr(numeric_only=True)
# Out:
#                          Unnamed: 0  product_star_rating  product_num_ratings  \
# Unnamed: 0                 1.000000            -0.108650             0.236651
# product_star_rating       -0.108650             1.000000             0.125740
# product_num_ratings        0.236651             0.125740             1.000000
# product_num_offers        -0.313941             0.001253            -0.103248
# is_best_seller             0.248094             0.201876            -0.103830
# is_amazon_choice          -0.155562             0.090631            -0.035781
# is_prime                  -0.546855             0.132807            -0.356207
# climate_pledge_friendly   -0.086035            -0.034112            -0.050850
# has_variations            -0.424577            -0.062900            -0.124221
# unit_count                 0.397001            -0.860200            -0.273278
#
#                          product_num_offers  is_best_seller  is_amazon_choice  \
# ...
